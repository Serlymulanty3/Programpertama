# %%
list_kosong = []

# %%
list_buah = ["pisang", "Nanas","Melon","Durian"]

# %%
list_angka = [100,200,1000,2000]

# %%
list_campuran = ["Nasi", 200,1000,5000, "ikan", True,False]

# %%
print ('list_kosong',list_kosong)
# Out:
# list_kosong []

# %%
print ('isi list buah ',list_buah)
# Out:
# isi list buah  ['pisang', 'Nanas', 'Melon', 'Durian']

# %%
print ('isi list angka',list_angka)
# Out:
# isi list angka [100, 200, 1000, 2000]

# %%
print ('isi list campuran',list_campuran)
# Out:
# isi list campuran ['Nasi', 200, 1000, 5000, 'ikan', True, False]

# %%
print(list_buah[0])
# Out:
# pisang

# %%
print(list_buah[1])
# Out:
# Nanas

# %%
print(list_buah[2])
# Out:
# Melon

# %%
print(list_buah[3])
# Out:
# Durian

# %%
print(list_buah[-1])
# Out:
# Durian

# %%
print(list_buah[0:1])
# Out:
# ['pisang']

# %%
print(list_buah[0:2])
# Out:
# ['pisang', 'Nanas']

# %%
print(list_buah[1:3])
# Out:
# ['Nanas', 'Melon']

# %%
print(list_buah[0:])
# Out:
# ['pisang', 'Nanas', 'Melon', 'Durian']

# %%
print(list_buah[1:])
# Out:
# ['Nanas', 'Melon', 'Durian']

# %%
print(list_buah)
# Out:
# ['pisang', 'Nanas', 'Melon', 'Durian']

# %%
list_buah[0]="jeruk"

# %%
list_buah[-1]="Mangga"

# %%
print(list_buah)
# Out:
# ['jeruk', 'Nanas', 'Melon', 'Mangga']

# %%
list_buah[1:3]=["buah Naga","pepaya"]

# %%
print(list_buah)
# Out:
# ['jeruk', 'buah Naga', 'pepaya', 'Mangga']

# %%
a =[1,2,3]
b=["a"]
c=[True, "b",False]

# %%
listbaru =a+b+c

# %%
print(listbaru)
# Out:
# [1, 2, 3, 'a', True, 'b', False]

# %%
print(list_buah)
# Out:
# ['jeruk', 'buah Naga', 'pepaya', 'Mangga']

# %%
list_buah.sort()
print(list_angka)
# Out:
# [100, 200, 1000, 2000]
