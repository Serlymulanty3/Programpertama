# %%
#akses nilai tuple python

# %%
tp1=('kancil','meja','kursi')

# %%
tp2= (23, 25,27,29,31)

# %%
tp3= "kucing","anjing","ulat","dia"

# %%
print("tuple 1[0]:",tp1[0])
# Out:
# tuple 1[0]: kancil

# %%
print("tuple 2[0:3]:",tp2[0:5])
# Out:
# tuple 2[0:3]: ('kucing', 'anjing', 'ulat', 'dia')

# %%
print("tuple 1[2:4]:",tp3[2:3])
# Out:
# tuple 1[2:4]: ('ulat',)

# %%
#jadi,buatlah tuple baru

# %%
tp1=('kancil','meja','kursi')

# %%
tp2= (23, 25,27,29,31)

# %%
tp3= "kucing","anjing","ulat","dia"

# %%
#tuple baru sebagai brikut

# %%
tp4=tp1+tp2

# %%
tp5=tp3+tp1

# %%
tp6=tp1+tp2+tp3

# %%
#hasil

# %%
print("tuple baru tp4",tp4)
# Out:
# tuple baru tp4 ('kancil', 'meja', 'kursi', 23, 25, 27, 29, 31)

# %%
print("tuple baru tp6",tp6)
# Out:
# tuple baru tp6 ('kancil', 'meja', 'kursi', 23, 25, 27, 29, 31, 'kucing', 'anjing', 'ulat', 'dia')

# %%
print("tuple baru tp5",tp5)
# Out:
# tuple baru tp5 ('kucing', 'anjing', 'ulat', 'dia', 'kancil', 'meja', 'kursi')

# %%
tp1=('kancil','meja','kursi')

# %%
tp2= (23, 25,27,29,31)

# %%
tp3= "kucing","anjing","ulat","dia"

# %%
#hapus tuple dengan statement del

# %%
del tp1

# %%
del tp2

# %%
del tp3

# %%
# lalu buat tuple yang di inginkan

# %%
tp1=('dia','gabut','pergi',564,29,3,20,4)

# %%
tp2=('ani','budi',54537,'anton','mail')

# %%
tp3=('pantai',"bukit",47438,"rumah",5545)

# %%
print("setelah menghapus tuple tp1:",tp1)
# Out:
# setelah menghapus tuple tp1: ('dia', 'gabut', 'pergi', 564, 29, 3, 20, 4)

# %%
print("setelah menghapus tuple tp2:",tp2)
# Out:
# setelah menghapus tuple tp2: ('ani', 'budi', 54537, 'anton', 'mail')

# %%
print("setelah menghapus tuple tp3:",tp3)
# Out:
# setelah menghapus tuple tp3: ('pantai', 'bukit', 47438, 'rumah', 5545)
