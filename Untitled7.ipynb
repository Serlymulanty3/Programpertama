# %%
# membuat tuple kosong

# %%
tuple_kosong=()

# %%
#membuat tuple dengan nilai-nilai

# %%
tuple_nilai=(23,10,20,23)

# %%
# membuat tuple tanda kurung(juga valid)

# %%
tuple_lain=1,2,3,4,5,6,7

# %%
# membuat tuple dengan tipe data yang berbeda

# %%
tuple_bercampur = (1,"hello", 3.14,True)

# %%
print ("isi tuple nilai-nilai:", tuple_nilai)
# Out:
# isi tuple nilai-nilai: (23, 10, 20, 23)

# %%
print("tipe data berbeda",tuple_bercampur)
# Out:
# tipe data berbeda (1, 'hello', 3.14, True)

# %%
print("tuple kosong",tuple_kosong)
# Out:
# tuple kosong ()

# %%
# Membuat tuple list buah

# %%
tuple_buah=('duku','jeruk','kelapa')

# %%
print("tuple list buah",tuple_buah)
# Out:
# tuple list buah ('duku', 'jerukpir', 'kelapa')
